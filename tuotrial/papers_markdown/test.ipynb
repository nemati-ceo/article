# %%
from paperflow import PaperPipeline

pipeline = PaperPipeline()
results = pipeline.search("machine learning", sources=["arxiv"], max_results=3)
print(f"Found {len(results.papers)} papers")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from researchflow import PaperPipeline
#       3 pipeline = PaperPipeline()
#       4 results = pipeline.search("machine learning", sources=["arxiv"], max_results=3)
#
# ModuleNotFoundError: No module named 'researchflow'
